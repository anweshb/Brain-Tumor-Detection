# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import load_model, save_model
from tensorflow.keras.preprocessing.image import load_img, img_to_array

# %%
my_model = load_model('tumor_model.h5')

# %%
def predict_img(image_path, target_size = (357,328), preprocessing_factor = 255):
    img = load_img(image_path, target_size=target_size)
    plt.imshow(img)
    
    img_array = img_to_array(img)
    
    img_batch = np.expand_dims(img_array, axis=0)
    
    img_batch /= preprocessing_factor
    
    pred = my_model.predict(img_batch)[0][0]
    
    if pred >= 0.5:
        print("Tumor Detected")
    else:
        print("No Tumor Detected")

# %%
predict_img('test_img.jfif')
# Out:
# Tumor Detected

# %%
predict_img('brain_tumor_final\\test\\0\\no230.jpg')
# Out:
# Tumor Detected

# %%
predict_img('brain_tumor_final\\test\\0\\no1200.jpg')
# Out:
# No Tumor Detected

# %%
predict_img('brain_tumor_final\\test\\1\\y172.jpg')
# Out:
# Tumor Detected

# %%
predict_img('brain_tumor_final\\test\\1\\y229.jpg')
# Out:
# Tumor Detected
